# %%
# !pip install pandas==1.3.3
# !pip install requests==2.26.0
# !mamba install bs4==4.10.0 -y
# !mamba install html5lib==1.1 -y
# !pip instal lxml==4.6.4
# !pip install plotly==5.3.1
# Out:
# Collecting pandas==1.3.3
#   Downloading pandas-1.3.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 83.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from pandas==1.3.3) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from pandas==1.3.3) (2022.1)
# Requirement already satisfied: numpy>=1.17.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from pandas==1.3.3) (1.21.6)
# Requirement already satisfied: six>=1.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas==1.3.3) (1.16.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
# Successfully installed pandas-1.3.3
# Collecting requests==2.26.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 KB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests==2.26.0) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests==2.26.0) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests==2.26.0) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests==2.26.0) (2.0.12)
# Installing collected packages: requests
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Uninstalling requests-2.27.1:
#       Successfully uninstalled requests-2.27.1
# Successfully installed requests-2.26.0
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.22.1) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['bs4==4.10.0']
#
# [+] 0.0s
# pkgs/main/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s
# pkgs/main/noarch   ━━╸━━━━━━━━━━━━━━━╸━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s[+] 0.1s
# pkgs/main/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/main/noarch   ━━╸━━━━━━━━━━━━━━━╸━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/r/noarch      ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s[+] 0.2s
# pkgs/main/linux-64 ━━━━━━━━━━━━━━━╸━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# pkgs/main/noarch   ━━━━╸━━━━━━━━━━━━━━━╸━━━━  12.3kB /  ??.?MB @  80.1kB/s  0.2s
# pkgs/r/linux-64    ━━━━━━╸━━━━━━━━━━━━━━━╸━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# pkgs/r/noarch      ━━━━━╸━━━━━━━━━━━━━━━╸━━━  12.3kB /  ??.?MB @  80.2kB/s  0.2s[+] 0.3s
# pkgs/main/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━━━  90.1kB /  ??.?MB @ 440.7kB/s  0.3s
# pkgs/main/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━━━ 237.6kB /  ??.?MB @   1.2MB/s  0.3s
# pkgs/r/linux-64    ━━━━━━━━╸━━━━━━━━━━━━━━━━ 213.1kB /  ??.?MB @   1.0MB/s  0.3s
# pkgs/r/noarch      ━━━━━━━╸━━━━━━━━━━━━━━━╸━ 241.7kB /  ??.?MB @   1.2MB/s  0.3s[+] 0.4s
# pkgs/main/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━━━  90.1kB /  ??.?MB @ 440.7kB/s  0.4s
# pkgs/main/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━━━ 237.6kB /  ??.?MB @   1.2MB/s  0.4s
# pkgs/r/linux-64    ━━━━━━━━╸━━━━━━━━━━━━━━━━ 213.1kB /  ??.?MB @   1.0MB/s  0.4s
# pkgs/r/noarch      ━━━━━━━╸━━━━━━━━━━━━━━━╸━ 241.7kB /  ??.?MB @   1.2MB/s  0.4s[+] 0.5s
# pkgs/main/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━━━  90.1kB /  ??.?MB @ 440.7kB/s  0.5s
# pkgs/main/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━━━ 237.6kB /  ??.?MB @   1.2MB/s  0.5s
# pkgs/r/linux-64    ━━━━━━━━╸━━━━━━━━━━━━━━━━ 213.1kB /  ??.?MB @   1.0MB/s  0.5s
# pkgs/r/noarch      ━━━━━━━╸━━━━━━━━━━━━━━━╸━ 241.7kB /  ??.?MB @   1.2MB/s  0.5s[+] 0.6s
# pkgs/main/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━━━  90.1kB /  ??.?MB @ 440.7kB/s  0.6s
# pkgs/main/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━━━ 237.6kB /  ??.?MB @   1.2MB/s  0.6s
# pkgs/r/linux-64    ━━━━━━━━╸━━━━━━━━━━━━━━━━ 213.1kB /  ??.?MB @   1.0MB/s  0.6s
# pkgs/r/noarch      ━━━━━━━╸━━━━━━━━━━━━━━━╸━ 241.7kB /  ??.?MB @   1.2MB/s  0.6s[+] 0.7s
# pkgs/main/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━━━  90.1kB /  ??.?MB @ 440.7kB/s  0.7s
# pkgs/main/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━━━ 237.6kB /  ??.?MB @   1.2MB/s  0.7s
# pkgs/r/linux-64    ━━━━━━━━╸━━━━━━━━━━━━━━━━ 213.1kB /  ??.?MB @   1.0MB/s  0.7s
# pkgs/r/noarch      ━━━━━━━╸━━━━━━━━━━━━━━━╸━ 241.7kB /  ??.?MB @   1.2MB/s  0.7s[+] 0.8s
# pkgs/main/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━━━  90.1kB /  ??.?MB @ 440.7kB/s  0.8s
# pkgs/main/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━━━ 237.6kB /  ??.?MB @   1.2MB/s  0.8s
# pkgs/r/linux-64    ━━━━━━━━╸━━━━━━━━━━━━━━━━ 213.1kB /  ??.?MB @   1.0MB/s  0.8s
# pkgs/r/noarch      ━━━━━━━╸━━━━━━━━━━━━━━━╸━ 241.7kB /  ??.?MB @   1.2MB/s  0.8s[+] 0.9s
# pkgs/main/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━━━  90.1kB /  ??.?MB @ 440.7kB/s  0.9s
# pkgs/main/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━━━ 237.6kB /  ??.?MB @   1.2MB/s  0.9s
# pkgs/r/linux-64    ━━━━━━━━╸━━━━━━━━━━━━━━━━ 213.1kB /  ??.?MB @   1.0MB/s  0.9s
# pkgs/r/noarch      ━━━━━━━╸━━━━━━━━━━━━━━━╸━ 241.7kB /  ??.?MB @   1.2MB/s  0.9s[+] 1.0s
# pkgs/main/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━━━  90.1kB /  ??.?MB @ 440.7kB/s  1.0s
# pkgs/main/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━━━ 237.6kB /  ??.?MB @   1.2MB/s  1.0s
# pkgs/r/linux-64    ━━━━━━━━╸━━━━━━━━━━━━━━━━ 213.1kB /  ??.?MB @   1.0MB/s  1.0s
# pkgs/r/noarch      ━━━━━━━╸━━━━━━━━━━━━━━━╸━ 241.7kB /  ??.?MB @   1.2MB/s  1.0s[+] 1.1s
# pkgs/main/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━━━  90.1kB /  ??.?MB @ 440.7kB/s  1.1s
# pkgs/main/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━━━ 237.6kB /  ??.?MB @   1.2MB/s  1.1s
# pkgs/r/linux-64    ━━━━━━━━╸━━━━━━━━━━━━━━━━ 213.1kB /  ??.?MB @   1.0MB/s  1.1s
# pkgs/r/noarch      ━━━━━━━╸━━━━━━━━━━━━━━━╸━ 241.7kB /  ??.?MB @   1.2MB/s  1.1s[+] 1.2s
# pkgs/main/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━━━  90.1kB /  ??.?MB @ 440.7kB/s  1.2s
# pkgs/main/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━━━ 237.6kB /  ??.?MB @   1.2MB/s  1.2s
# pkgs/r/linux-64    ━━━━━━━━╸━━━━━━━━━━━━━━━━ 213.1kB /  ??.?MB @   1.0MB/s  1.2s
# pkgs/r/noarch      ━━━━━━━╸━━━━━━━━━━━━━━━╸━ 241.7kB /  ??.?MB @   1.2MB/s  1.2s[+] 1.3s
# pkgs/main/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━━━  90.1kB /  ??.?MB @ 440.7kB/s  1.3s
# pkgs/main/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━━━ 237.6kB /  ??.?MB @   1.2MB/s  1.3s
# pkgs/r/linux-64    ━━━━━━━━╸━━━━━━━━━━━━━━━━ 213.1kB /  ??.?MB @   1.0MB/s  1.3s
# pkgs/r/noarch      ━━━━━━━╸━━━━━━━━━━━━━━━╸━ 241.7kB /  ??.?MB @   1.2MB/s  1.3s[+] 1.4s
# pkgs/main/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━━━  90.1kB /  ??.?MB @ 440.7kB/s  1.4s
# pkgs/main/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━━━ 237.6kB /  ??.?MB @   1.2MB/s  1.4s
# pkgs/r/linux-64    ━━━━━━━━╸━━━━━━━━━━━━━━━━ 213.1kB /  ??.?MB @   1.0MB/s  1.4s
# pkgs/r/noarch      ━━━━━━━╸━━━━━━━━━━━━━━━╸━ 241.7kB /  ??.?MB @   1.2MB/s  1.4s[+] 1.5s
# pkgs/main/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━━━  90.1kB /  ??.?MB @ 440.7kB/s  1.5s
# pkgs/main/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━━━ 237.6kB /  ??.?MB @   1.2MB/s  1.5s
# pkgs/r/linux-64    ━━━━━━━━╸━━━━━━━━━━━━━━━━ 213.1kB /  ??.?MB @   1.0MB/s  1.5s
# pkgs/r/noarch      ━━━━━━━╸━━━━━━━━━━━━━━━╸━ 241.7kB /  ??.?MB @   1.2MB/s  1.5s[+] 1.6s
# pkgs/main/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━━━  90.1kB /  ??.?MB @ 440.7kB/s  1.6s
# pkgs/main/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━━━ 237.6kB /  ??.?MB @   1.2MB/s  1.6s
# pkgs/r/linux-64    ━━━━━━━━╸━━━━━━━━━━━━━━━━ 213.1kB /  ??.?MB @   1.0MB/s  1.6s
# pkgs/r/noarch      ━━━━━━━╸━━━━━━━━━━━━━━━╸━ 241.7kB /  ??.?MB @   1.2MB/s  1.6s[+] 1.7s
# pkgs/main/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━━━  90.1kB /  ??.?MB @ 440.7kB/s  1.7s
# pkgs/main/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━━━ 237.6kB /  ??.?MB @   1.2MB/s  1.7s
# pkgs/r/linux-64    ━━━━━━━━╸━━━━━━━━━━━━━━━━ 213.1kB /  ??.?MB @   1.0MB/s  1.7s
# pkgs/r/noarch      ━━━━━━━╸━━━━━━━━━━━━━━━╸━ 241.7kB /  ??.?MB @   1.2MB/s  1.7s[+] 1.8s
# pkgs/main/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━━━  90.1kB /  ??.?MB @ 440.7kB/s  1.8s
# pkgs/main/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━━━ 237.6kB /  ??.?MB @   1.2MB/s  1.8s
# pkgs/r/linux-64    ━━━━━━━━╸━━━━━━━━━━━━━━━━ 213.1kB /  ??.?MB @   1.0MB/s  1.8s
# pkgs/r/noarch      ━━━━━━━╸━━━━━━━━━━━━━━━╸━ 241.7kB /  ??.?MB @   1.2MB/s  1.8s[+] 1.9s
# pkgs/main/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━━━  90.1kB /  ??.?MB @ 440.7kB/s  1.9s
# pkgs/main/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━━━ 237.6kB /  ??.?MB @   1.2MB/s  1.9s
# pkgs/r/linux-64    ━━━━━━━━╸━━━━━━━━━━━━━━━━ 213.1kB /  ??.?MB @   1.0MB/s  1.9s
# pkgs/r/noarch      ━━━━━━━╸━━━━━━━━━━━━━━━╸━ 241.7kB /  ??.?MB @   1.2MB/s  1.9s[+] 2.0s
# pkgs/main/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━━━  90.1kB /  ??.?MB @ 440.7kB/s  2.0s
# pkgs/main/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━━━ 237.6kB /  ??.?MB @   1.2MB/s  2.0s
# pkgs/r/linux-64    ━━━━━━━━╸━━━━━━━━━━━━━━━━ 213.1kB /  ??.?MB @   1.0MB/s  2.0s
# pkgs/r/noarch      ━━━━━━━╸━━━━━━━━━━━━━━━╸━ 241.7kB /  ??.?MB @   1.2MB/s  2.0spkgs/r/noarch                                      482.4kB @ 238.1kB/s  2.0s
# [+] 2.1s
# pkgs/main/linux-64 ━━╸━━━━━━━━━━━━━━━╸━━━━━━ 327.7kB /  ??.?MB @ 160.2kB/s  2.1s
# pkgs/r/linux-64    ━━━━━━━━━╸━━━━━━━━━━━━━━━ 442.4kB /  ??.?MB @ 216.3kB/s  2.1spkgs/main/noarch                                   809.7kB @ 389.4kB/s  2.1s
# pkgs/r/linux-64                                      1.1MB @ 498.0kB/s  2.1s
# [+] 2.2s
# pkgs/main/linux-64 ━━━━╸━━━━━━━━━━━━━━━╸━━━━   1.2MB /  ??.?MB @ 544.2kB/s  2.2s[+] 2.3s
# pkgs/main/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━╸━   2.6MB /  ??.?MB @   1.1MB/s  2.3s[+] 2.4s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   3.1MB /  ??.?MB @   1.3MB/s  2.4s[+] 2.5s
# pkgs/main/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━━━   3.5MB /  ??.?MB @   1.4MB/s  2.5s[+] 2.6s
# pkgs/main/linux-64 ━━━━━━━━━━━━━━╸━━━━━━━━━━   4.0MB /  ??.?MB @   1.6MB/s  2.6s[+] 2.7s
# pkgs/main/linux-64 ━━━━━━━━━━━━━━━━━━━━━━━━   4.5MB @   1.7MB/s Finalizing  2.7s[+] 2.8s
# [+] 2.9s
# pkgs/main/linux-64                                 @   1.7MB/s  2.7s
#
# Pinned packages:
#   - python 3.7.*
#
#
# Transaction
#
#   Prefix: /home/jupyterlab/conda/envs/python
#
#   Updating specs:
#
#    - bs4==4.10.0
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package              Version  Build         Channel                 Size
# ────────────────────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────────────────────
#
#   + beautifulsoup4      4.10.0  pyh06a4308_0  pkgs/main/noarch        87kB
#   + bs4                 4.10.0  hd3eb1b0_0    pkgs/main/noarch        10kB
#   + soupsieve            2.3.1  pyhd3eb1b0_0  pkgs/main/noarch        35kB
#
#   Upgrade:
# ────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates  2021.10.8  ha878542_0    installed
#   + ca-certificates  2022.4.26  h06a4308_0    pkgs/main/linux-64     127kB
#   - openssl             1.1.1n  h166bdaf_0    installed
#   + openssl             1.1.1o  h7f8727e_0    pkgs/main/linux-64       3MB
#
#   Summary:
#
#   Install: 3 packages
#   Upgrade: 2 packages
#
#   Total download: 3MB
#
# ────────────────────────────────────────────────────────────────────────────
#
# [+] 0.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B                            0.0s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 0.1s
# Downloading  (5) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B beautifulsoup4             0.0s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0sbeautifulsoup4                                      86.6kB @ 592.3kB/s  0.1s
# [+] 0.2s
# Downloading  (4) ━━━━━━━━━━━━━━━━━━━━━━━  86.6kB bs4                        0.1s
# Extracting   (1) ━━━━━━━━━╸━━━━━━━━━━━━━       0 beautifulsoup4             0.0sbs4                                                 10.2kB @  40.2kB/s  0.3s
# soupsieve                                           35.0kB @ 133.8kB/s  0.3s
# ca-certificates                                    126.7kB @ 458.0kB/s  0.3s
# [+] 0.3s
# Downloading  (1) ╸━━━━━━━━━━━━━━━━━━━━━━ 258.9kB openssl                    0.2s
# Extracting   (4) ━━━━━━━━━━╸━━━━━━━━━━━━       0 beautifulsoup4             0.1sopenssl                                              2.6MB @   7.5MB/s  0.4s
# [+] 0.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━━━━━━━━━╸━━━━━━━━━━━       0 beautifulsoup4             0.2s[+] 0.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━━━━━━━━━━━╸━━━━━━━━━       0 beautifulsoup4             0.3s[+] 0.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━━━━━━━━━━━━╸━━━━━━━━       0 bs4                        0.4s[+] 0.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━━━━━━━━━━━━━╸━━━━━━━       0 bs4                        0.5s[+] 0.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ╸━━━━━━━━━━━━━━━╸━━━━━━       0 bs4                        0.6s[+] 0.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━╸━━━━━━━━━━━━━━━╸━━━━━       0 bs4                        0.7s[+] 1.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━╸━━━━━━━━━━━━━━━╸━━━━       0 ca-certificates            0.8s[+] 1.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━╸━━━━━━━━━━━━━━━╸━━━       0 ca-certificates            0.9s[+] 1.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━━╸━━━━━━━━━━━━━━━╸━━       0 ca-certificates            1.0s[+] 1.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━━━╸━━━━━━━━━━━━━━━╸━       0 ca-certificates            1.1s[+] 1.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━━━━╸━━━━━━━━━━━━━━━━       0 openssl                    1.2s[+] 1.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━━━━━━╸━━━━━━━━━━━━━━       0 openssl                    1.3s[+] 1.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━━━━━━━╸━━━━━━━━━━━━━       0 openssl                    1.4s[+] 1.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━━━━━━━━╸━━━━━━━━━━━━       0 openssl                    1.5s[+] 1.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━━━━━━━━━╸━━━━━━━━━━━       0 soupsieve                  1.6s[+] 1.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━━━━━━━━━━╸━━━━━━━━━━       0 soupsieve                  1.7s[+] 2.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━━━━━╸━━━━━━━━━━━━━━━       0 soupsieve                  1.8s[+] 2.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━━━━━━╸━━━━━━━━━━━━━━       0 soupsieve                  1.9s[+] 2.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━━━━━━━╸━━━━━━━━━━━━━       0 beautifulsoup4             2.0s[+] 2.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━━━━━━━━╸━━━━━━━━━━━━       0 beautifulsoup4             2.1s[+] 2.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━━━━━━━━━╸━━━━━━━━━━━       0 beautifulsoup4             2.2s[+] 2.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━━━━━━━━━━━╸━━━━━━━━━       0 beautifulsoup4             2.3s[+] 2.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━━━━━━━━━━━━╸━━━━━━━━       0 bs4                        2.4s[+] 2.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━━━━━━━━━━━━━╸━━━━━━━       0 bs4                        2.5s[+] 2.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ╸━━━━━━━━━━━━━━━╸━━━━━━       0 bs4                        2.6s[+] 2.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━╸━━━━━━━━━━━━━━━╸━━━━━       0 bs4                        2.7s[+] 3.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━╸━━━━━━━━━━━━━━━╸━━━━       0 ca-certificates            2.8s[+] 3.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (5) ━━━╸━━━━━━━━━━━━━━━╸━━━       0 ca-certificates            2.9s[+] 3.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (4) ━━━╸━━━━━━━━━━━━━━━━━━━       1 ca-certificates            3.0s[+] 3.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (4) ━━━╸━━━━━━━━━━━━━━━━━━━       1 ca-certificates            3.1s[+] 3.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (4) ━━━╸━━━━━━━━━━━━━━━━━━━       1 openssl                    3.2s[+] 3.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (4) ━━━╸━━━━━━━━━━━━━━━━━━━       1 openssl                    3.3s[+] 3.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (4) ━━━╸━━━━━━━━━━━━━━━━━━━       1 openssl                    3.4s[+] 3.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (3) ━━━━━━━━╸━━━━━━━━━━━━━━       2 openssl                    3.5s[+] 3.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   2.9MB                            0.3s
# Extracting   (2) ━━━━━━━━━━━━╸━━━━━━━━━━       3 soupsieve                  3.6sPreparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.22.1) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['html5lib==1.1']
#
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# pkgs/r/linux-64                                             Using cache
# pkgs/r/noarch                                               Using cache
#
# Pinned packages:
#   - python 3.7.*
#
#
# Transaction
#
#   Prefix: /home/jupyterlab/conda/envs/python
#
#   Updating specs:
#
#    - html5lib==1.1
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package         Version  Build         Channel                Size
# ──────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────
#
#   + html5lib          1.1  pyhd3eb1b0_0  pkgs/main/noarch       93kB
#   + webencodings    0.5.1  py37_1        pkgs/main/linux-64     20kB
#
#   Summary:
#
#   Install: 2 packages
#
#   Total download: 113kB
#
# ──────────────────────────────────────────────────────────────────────
#
# [+] 0.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B                            0.0s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 0.1s
# Downloading  (2) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B html5lib                   0.0s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0shtml5lib                                            93.0kB @ 693.8kB/s  0.1s
# webencodings                                        19.6kB @ 137.2kB/s  0.1s
# [+] 0.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 112.6kB                            0.1s
# Extracting   (2) ━━━━━━━╸━━━━━━━━━━━━━━━       0 html5lib                   0.0s[+] 0.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 112.6kB                            0.1s
# Extracting   (2) ━━━━━━━━╸━━━━━━━━━━━━━━       0 html5lib                   0.1s[+] 0.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 112.6kB                            0.1s
# Extracting   (2) ━━━━━━━━━╸━━━━━━━━━━━━━       0 html5lib                   0.2s[+] 0.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 112.6kB                            0.1s
# Extracting   (2) ━━━━━━━━━━╸━━━━━━━━━━━━       0 html5lib                   0.3s[+] 0.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 112.6kB                            0.1s
# Extracting   (2) ━━━━━━━━━━━╸━━━━━━━━━━━       0 webencodings               0.4s[+] 0.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 112.6kB                            0.1s
# Extracting   (2) ━━━━━━━━━━━━╸━━━━━━━━━━       0 webencodings               0.5s[+] 0.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 112.6kB                            0.1s
# Extracting   (2) ━━━━━━━╸━━━━━━━━━━━━━━━       0 webencodings               0.6s[+] 0.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 112.6kB                            0.1s
# Extracting   (2) ━━━━━━━━╸━━━━━━━━━━━━━━       0 webencodings               0.7s[+] 1.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 112.6kB                            0.1s
# Extracting   (2) ━━━━━━━━━╸━━━━━━━━━━━━━       0 html5lib                   0.8s[+] 1.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 112.6kB                            0.1s
# Extracting   (2) ━━━━━━━━━━━╸━━━━━━━━━━━       0 html5lib                   0.9s[+] 1.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 112.6kB                            0.1s
# Extracting   (2) ━━━━━━━━━━━━╸━━━━━━━━━━       0 html5lib                   1.0s[+] 1.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 112.6kB                            0.1s
# Extracting   (1) ━━━━━━━━━━╸━━━━━━━━━━━━       1 html5lib                   1.1sPreparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# ERROR: unknown command "instal" - maybe you meant "install"
# Collecting plotly==5.3.1
#   Downloading plotly-5.3.1-py2.py3-none-any.whl (23.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.9/23.9 MB 51.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from plotly==5.3.1) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from plotly==5.3.1) (8.0.1)
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.7.0
#     Uninstalling plotly-5.7.0:
#       Successfully uninstalled plotly-5.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dash 2.3.1 requires dash-core-components==2.0.0, which is not installed.
# dash 2.3.1 requires dash-html-components==2.0.0, which is not installed.
# dash 2.3.1 requires dash-table==5.0.0, which is not installed.
# Successfully installed plotly-5.3.1

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Using Webscraping to Extract Stock Data Example
#
#
# First we must use the request library to downlaod the webpage, and extract the text. We will extract Netflix stock data https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/netflix_data_webpage.html.

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/netflix_data_webpage.html"

# %%
data  = requests.get(url).text

# %% [markdown]
# Next we must parse the text into html using beautiful_soup

# %%
soup=BeautifulSoup(data, "html5lib")

# %% [markdown]
# Now we can turn the html table into a pandas dataframe

# %%
netflix_data=pd.DataFrame(columns=["Date", "Open", "High", "Low", "Close", "Volume"])

# First we isolate the body of the table which contains all the information
# Then we loop through each row and find all the column values for each row

for row in soup.find("tbody").find_all("tr"):
    col=row.find_all("td")
    date=col[0].text
    open=col[1].text
    high=col[2].text
    low=col[3].text
    close=col[4].text
    adj_close=col[5].text
    volume=col[6].text
    
    # Finally we append the data of each row to the table
    netflix_data=netflix_data.append({"Date":date, "Open":open, "High":high, "Low":low, "Close":close, "Adj Close":adj_close, "Volume":volume}, ignore_index=True)

# %%
netflix_data.head()
# Out:
#            Date    Open    High     Low   Close       Volume Adj Close
# 0  Jun 01, 2021  504.01  536.13  482.14  528.21   78,560,600    528.21
# 1  May 01, 2021  512.65  518.95  478.54  502.81   66,927,600    502.81
# 2  Apr 01, 2021  529.93  563.56  499.00  513.47  111,573,300    513.47
# 3  Mar 01, 2021  545.57  556.99  492.85  521.66   90,183,900    521.66
# 4  Feb 01, 2021  536.79  566.65  518.28  538.85   61,902,300    538.85

# %%
netflix_data.tail()
# Out:
#             Date    Open    High     Low   Close       Volume Adj Close
# 65  Jan 01, 2016  109.00  122.18   90.11   91.84  488,193,200     91.84
# 66  Dec 01, 2015  124.47  133.27  113.85  114.38  319,939,200    114.38
# 67  Nov 01, 2015  109.20  126.60  101.86  123.33  320,321,800    123.33
# 68  Oct 01, 2015  102.91  115.83   96.26  108.38  446,204,400    108.38
# 69  Sep 01, 2015  109.35  111.24   93.55  103.26  497,401,200    103.26

# %% [markdown]
# We can also use the pandas read_html function using the url

# %%
read_html_pandas_data=pd.read_html(url)

# %% [markdown]
# Or we can convert the BeautifulSoup object to a string

# %%
read_html_pandas_data=pd.read_html(str(soup))

# %% [markdown]
# Beacause there is only one table on the page, we just take the first table in the list returned

# %%
Netflix_dataframe=read_html_pandas_data[0]
Netflix_dataframe.head()
# Out:
#            Date    Open    High     Low  Close* Adj Close**     Volume
# 0  Jun 01, 2021  504.01  536.13  482.14  528.21      528.21   78560600
# 1  May 01, 2021  512.65  518.95  478.54  502.81      502.81   66927600
# 2  Apr 01, 2021  529.93  563.56  499.00  513.47      513.47  111573300
# 3  Mar 01, 2021  545.57  556.99  492.85  521.66      521.66   90183900
# 4  Feb 01, 2021  536.79  566.65  518.28  538.85      538.85   61902300

# %%
Netflix_dataframe.tail()
# Out:
#                                                  Date  \
# 66                                       Dec 01, 2015
# 67                                       Nov 01, 2015
# 68                                       Oct 01, 2015
# 69                                       Sep 01, 2015
# 70  *Close price adjusted for splits.**Adjusted cl...
#
#                                                  Open  \
# 66                                             124.47
# 67                                             109.20
# 68                                             102.91
# 69                                             109.35
# 70  *Close price adjusted for splits.**Adjusted cl...
#
#                                                  High  \
# 66                                             133.27
# 67                                             126.60
# 68                                             115.83
# 69                                             111.24
# 70  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Low  \
# 66                                             113.85
# 67                                             101.86
# 68                                              96.26
# 69                                              93.55
# 70  *Close price adjusted for splits.**Adjusted cl...
#
#                                                Close*  \
# 66                                             114.38
# 67                                             123.33
# 68                                             108.38
# 69                                             103.26
# 70  *Close price adjusted for splits.**Adjusted cl...
#
#                                           Adj Close**  \
# 66                                             114.38
# 67                                             123.33
# 68                                             108.38
# 69                                             103.26
# 70  *Close price adjusted for splits.**Adjusted cl...
#
#                                                Volume
# 66                                          319939200
# 67                                          320321800
# 68                                          446204400
# 69                                          497401200
# 70  *Close price adjusted for splits.**Adjusted cl...
